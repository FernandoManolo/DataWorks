# %%
# The code was removed by Watson Studio for sharing.
# Out:
#                         Field  Very interested  Somewhat interested  \
# 0   Big Data (Spark / Hadoop)             1332                  729
# 1  Data Analysis / Statistics             1688                  444
# 2             Data Journalism              429                 1081
# 3          Data Visualization             1340                  734
# 4               Deep Learning             1263                  770
#
#    Not interested
# 0             127
# 1              60
# 2             610
# 3             102
# 4             136

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df_inte = df_data_1.sort_values(by=['Very interested'],ascending=False)
df_inte.head()
# Out:
#                         Field  Very interested  Somewhat interested  \
# 1  Data Analysis / Statistics             1688                  444
# 5            Machine Learning             1629                  477
# 3          Data Visualization             1340                  734
# 0   Big Data (Spark / Hadoop)             1332                  729
# 4               Deep Learning             1263                  770
#
#    Not interested
# 1              60
# 5              74
# 3             102
# 0             127
# 4             136

# %%
df_inte.set_index('Field', inplace=True)

# %%
df_inte.head()
# Out:
#                             Very interested  Somewhat interested  \
# Field
# Data Analysis / Statistics             1688                  444
# Machine Learning                       1629                  477
# Data Visualization                     1340                  734
# Big Data (Spark / Hadoop)              1332                  729
# Deep Learning                          1263                  770
#
#                             Not interested
# Field
# Data Analysis / Statistics              60
# Machine Learning                        74
# Data Visualization                     102
# Big Data (Spark / Hadoop)              127
# Deep Learning                          136

# %%
(100. * df_inte / df_inte.sum()).round(2).astype(str) + '%'
# Out:
#                            Very interested Somewhat interested Not interested
# Field
# Data Analysis / Statistics          21.98%              10.48%          5.41%
# Machine Learning                    21.21%              11.26%          6.67%
# Data Visualization                  17.45%              17.33%           9.2%
# Big Data (Spark / Hadoop)           17.34%              17.21%         11.45%
# Deep Learning                       16.44%              18.18%         12.26%
# Data Journalism                      5.59%              25.53%          55.0%

# %%
import matplotlib.pyplot as plt
colors = '#5cb85c', '#5bc0de', '#d9534f'
ax = (df_inte.div(df_inte.sum(1), axis=0)).plot(kind='bar',figsize=(15,4),width = 0.8,color = colors,edgecolor=None)
plt.title('Percentage of Respondents interest in Data Science Areas', fontsize=16)
#plt.legend(labels=df_inte.columns,fontsize= 14)
plt.xticks(fontsize=14)
for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.yticks([])
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate('{:.0%}'.format(height), (p.get_x()+.15*width, p.get_y() + height + 0.01))
ax
